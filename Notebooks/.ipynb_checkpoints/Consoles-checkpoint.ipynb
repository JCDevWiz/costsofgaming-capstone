# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
consoles = pd.read_csv('Data/best-selling_game_consoles.csv')
consoles.head(2)
# Out:
#   Console Name       Type Company  Released Year  Discontinuation Year  \
# 0      Telstar  Dedicated  Coleco           1976                  1978
# 1   Atari 2600       Home   Atari           1977                  1992
#
#    Units sold (million)  Units_number    Price Price_Inflation  \
# 0                   1.0     1000000.0   $50.00         $285.00
# 1                  30.0    30000000.0  $199.00       $1,064.00
#
#              Revenue                                 Remarks       Mods
# 0     $50,000,000.00  Final sales are greater than 1 million  1,000,000
# 1  $5,970,000,000.00                                     NaN        NaN

# %% [markdown]
# Data Cleaning done in excel: I added the 'Price' column based on https://www.inflationstation.net/, I used https://www.in2013dollars.com/ to find inflation numbers based on 'Price', giving me my 'Price_Inflation'. I then added the 'Mods' column to multiply the 'Units Sold' column by it and get the 'Units_number' column. Then some simple multiplication with 'Units_number' and 'Price' led me to an estimated 'Revenue'.

# %%
consoles.drop(columns= 'Mods')
# Out:
#                  Console Name                 Type                  Company  \
# 0                     Telstar            Dedicated                   Coleco
# 1                  Atari 2600                 Home                    Atari
# 2               Color TV-Game            Dedicated                 Nintendo
# 3            Magnavox Odyssey                 Home         Magnavox/Philips
# 4                Game & Watch             Handheld                 Nintendo
# 5               Intellivision                 Home                   Mattel
# 6                  Atari 5200                 Home                    Atari
# 7                ColecoVision                 Home                   Coleco
# 8                         NES                 Home                 Nintendo
# 9                  Atari 7800                 Home                    Atari
# 10        Famicom Disk System  Home console add-on                 Nintendo
# 11         Sega Master System                 Home                     Sega
# 12    PC Engine/TurboGrafx-16                 Home  NEC/Hudson Soft[note 6]
# 13           PC Engine CD-ROM  Home console add-on                      NEC
# 14               Sega Genesis                 Home                     Sega
# 15                 Atari Lynx             Handheld                    Atari
# 16                   Game Boy             Handheld                 Nintendo
# 17               Philips CD-i                 Home                  Philips
# 18             Sega Game Gear             Handheld                     Sega
# 19                       SNES                 Home                 Nintendo
# 20                    Sega CD  Home console add-on                     Sega
# 21                      Dendy                 Home             Micro Genius
# 22                  Sega Pico                 Home                     Sega
# 23                PlayStation                 Home                     Sony
# 24                Sega Saturn                 Home                     Sega
# 25                Nintendo 64                 Home                 Nintendo
# 26                  Dreamcast                 Home                     Sega
# 27             Game Boy Color             Handheld                 Nintendo
# 28                 WonderSwan             Handheld                   Bandai
# 29              PlayStation 2                 Home                     Sony
# 30           Game Boy Advance             Handheld                 Nintendo
# 31                   GameCube                 Home                 Nintendo
# 32                       Xbox                 Home                Microsoft
# 33                     N-Gage             Handheld                    Nokia
# 34                Nintendo DS             Handheld                 Nintendo
# 35       PlayStation Portable             Handheld                     Sony
# 36                   Xbox 360                 Home                Microsoft
# 37              PlayStation 3                 Home                     Sony
# 38                        Wii                 Home                 Nintendo
# 39               Nintendo 3DS             Handheld                 Nintendo
# 40           PlayStation Vita             Handheld                     Sony
# 41                      Wii U                 Home                 Nintendo
# 42              PlayStation 4                 Home                     Sony
# 43                   Xbox One                 Home                Microsoft
# 44        NES Classic Edition            Dedicated                 Nintendo
# 45            Nintendo Switch               Hybrid                 Nintendo
# 46  Super NES Classic Edition            Dedicated                 Nintendo
# 47              PlayStation 5                 Home                     Sony
# 48            Xbox Series X/S                 Home                Microsoft
#
#     Released Year  Discontinuation Year  Units sold (million)  Units_number  \
# 0            1976                  1978                  1.00     1000000.0
# 1            1977                  1992                 30.00    30000000.0
# 2            1977                  1980                  3.00     3000000.0
# 3            1972                  1975                  2.00     2000000.0
# 4            1980                  1991                 43.40    43400000.0
# 5            1980                  1990                  3.00     3000000.0
# 6            1982                  1984                  1.00     1000000.0
# 7            1982                  1985                  2.00     2000000.0
# 8            1983                  2003                 61.91    61910000.0
# 9            1986                  1991                  1.00     1000000.0
# 10           1986                  1992                  4.50     4500000.0
# 11           1986                  1996                 13.00    13000000.0
# 12           1989                  1994                 10.00    10000000.0
# 13           1988                  1998                  1.92     1920000.0
# 14           1988                  1997                 30.75    30750000.0
# 15           1989                  1995                  1.00     1000000.0
# 16           1989                  2003                 64.42    64420000.0
# 17           1990                  1998                  1.00     1000000.0
# 18           1990                  1997                 10.62    10620000.0
# 19           1990                  2003                 49.10    49100000.0
# 20           1991                  1996                  2.24     2240000.0
# 21           1992                  1998                  6.00     6000000.0
# 22           1993                  1998                  3.40     3400000.0
# 23           1994                  2006                102.49   102490000.0
# 24           1994                  2000                  9.26     9260000.0
# 25           1996                  2002                 32.93    32930000.0
# 26           1998                  2001                  9.13     9130000.0
# 27           1998                  2003                 44.06    44060000.0
# 28           1999                  2018                  3.50     3500000.0
# 29           2000                  2013                155.00   155000000.0
# 30           2001                  2010                 81.51    81510000.0
# 31           2001                  2007                 21.74    21740000.0
# 32           2001                  2009                 24.00    24000000.0
# 33           2003                  2005                  3.00     3000000.0
# 34           2004                  2013                154.02   154020000.0
# 35           2004                  2014                 82.00    82000000.0
# 36           2005                  2016                 84.00    84000000.0
# 37           2006                  2017                 87.40    87400000.0
# 38           2006                  2013                101.63   101630000.0
# 39           2011                  2020                 75.94    75940000.0
# 40           2011                  2019                 15.00    15000000.0
# 41           2012                  2017                 13.56    13560000.0
# 42           2013                     0                117.20   117200000.0
# 43           2013                  2020                 58.50    58500000.0
# 44           2016                  2018                  3.56     3560000.0
# 45           2017                     0                122.55   122550000.0
# 46           2017                  2018                  5.28     5280000.0
# 47           2020                     0                 30.00    30000000.0
# 48           2020                     0                 18.50    18500000.0
#
#       Price Price_Inflation             Revenue  \
# 0    $50.00         $285.00      $50,000,000.00
# 1   $199.00       $1,064.00   $5,970,000,000.00
# 2    $45.00         $241.00     $135,000,000.00
# 3   $100.00         $775.00     $200,000,000.00
# 4    $50.00         $197.00   $2,170,000,000.00
# 5   $299.00       $1,176.00     $897,000,000.00
# 6   $269.00         $903.00     $269,000,000.00
# 7   $175.00         $588.00     $350,000,000.00
# 8   $199.00         $647.00  $12,320,090,000.00
# 9   $139.00         $411.00     $139,000,000.00
# 10   $80.00         $236.00     $360,000,000.00
# 11  $200.00         $591.00   $2,600,000,000.00
# 12  $199.00         $520.00   $1,990,000,000.00
# 13  $399.00       $1,093.00     $766,080,000.00
# 14  $189.00         $518.00   $5,811,750,000.00
# 15  $179.00         $468.00     $179,000,000.00
# 16   $89.00         $233.00   $5,733,380,000.00
# 17  $799.00       $1,981.00     $799,000,000.00
# 18  $149.00         $369.00   $1,582,380,000.00
# 19  $199.00         $465.00   $9,770,900,000.00
# 20  $299.00         $493.00     $669,760,000.00
# 21   $94.00         $217.00     $564,000,000.00
# 22  $139.00         $312.00     $472,600,000.00
# 23  $299.00         $654.00  $30,644,510,000.00
# 24  $399.00         $872.00   $3,694,740,000.00
# 25  $199.00         $411.00   $6,553,070,000.00
# 26  $199.00         $396.00   $1,816,870,000.00
# 27   $80.00         $159.00   $3,524,800,000.00
# 28   $31.00          $60.00     $108,500,000.00
# 29  $299.00         $563.00  $46,345,000,000.00
# 30   $99.00         $181.00   $8,069,490,000.00
# 31  $199.00         $364.00   $4,326,260,000.00
# 32  $299.00         $547.00   $7,176,000,000.00
# 33  $299.00         $526.00     $897,000,000.00
# 34  $149.00         $256.00  $22,948,980,000.00
# 35  $249.00         $427.00  $20,418,000,000.00
# 36  $299.00         $496.00  $25,116,000,000.00
# 37  $499.00         $802.00  $43,612,600,000.00
# 38  $249.00         $400.00  $25,305,870,000.00
# 39  $249.00         $359.00  $18,909,060,000.00
# 40  $249.00         $359.00   $3,735,000,000.00
# 41  $349.00         $492.00   $4,732,440,000.00
# 42  $399.00         $555.00  $46,762,800,000.00
# 43  $499.00         $694.00  $29,191,500,000.00
# 44   $60.00          $81.00     $213,600,000.00
# 45  $299.00         $395.00  $36,642,450,000.00
# 46   $80.00         $106.00     $422,400,000.00
# 47  $499.00         $625.00  $14,970,000,000.00
# 48  $499.00         $625.00   $9,231,500,000.00
#
#                                               Remarks
# 0              Final sales are greater than 1 million
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6              Final sales are greater than 1 million
# 7              Final sales are greater than 2 million
# 8                                                 NaN
# 9              Final sales are greater than 1 million
# 10                                                NaN
# 11  Estimated between 10-13 million. Fun Fact The ...
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15             Final sales are greater than 1 million
# 16  The Game Boy (1989) and the Game Boy Color (19...
# 17             Final sales are greater than 1 million
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22           Final sales are greater than 3.4 million
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29           Final sales are greater than 155 million
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                    Estimated between 80-82 million
# 36            Final sales are greater than 84 million
# 37          Final sales are greater than 87.4 million
# 38                                                NaN
# 39                                                NaN
# 40                    Estimated between 10-15 million
# 41                                                NaN
# 42                                                NaN
# 43                  Estimated between 51-58.5 million
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                  Approximately around 18.5 million

# %%
consoles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Console Name          49 non-null     object
#  1   Type                  49 non-null     object
#  2   Company               49 non-null     object
#  3   Released Year         49 non-null     int64
#  4   Discontinuation Year  49 non-null     int64
#  5   Units sold (million)  49 non-null     float64
#  6   Units_number          49 non-null     float64
#  7   Price                 49 non-null     object
#  8   Price_Inflation       49 non-null     object
#  9   Revenue               49 non-null     object
#  10  Remarks               16 non-null     object
#  11  Mods                  1 non-null      object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 4.7+ KB

# %%
consoles['Price'] = consoles['Price'].str.replace('$', '').astype(float)

# %%
consoles['Price_Inflation'] = consoles['Price_Inflation'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
consoles['Revenue'] = consoles['Revenue'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
consoles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Console Name          49 non-null     object
#  1   Type                  49 non-null     object
#  2   Company               49 non-null     object
#  3   Released Year         49 non-null     int64
#  4   Discontinuation Year  49 non-null     int64
#  5   Units sold (million)  49 non-null     float64
#  6   Units_number          49 non-null     float64
#  7   Price                 49 non-null     float64
#  8   Price_Inflation       49 non-null     float64
#  9   Revenue               49 non-null     float64
#  10  Remarks               16 non-null     object
#  11  Mods                  1 non-null      object
# dtypes: float64(5), int64(2), object(5)
# memory usage: 4.7+ KB

# %% [markdown]
# Question: The real cost of gaming over time, adjusted for inflation and is it cheaper or more expensive now than in the 80s (40 years)?

# %%
sortedPrice = consoles.sort_values('Price')

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(
    x=sortedPrice["Released Year"],
    y=sortedPrice["Price"],
    line_kws={"color": "red", "linewidth": 1.5},
    ax=ax
)
# Out:
# <Axes: xlabel='Released Year', ylabel='Price'>

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(
    x=sortedPrice["Released Year"],
    y=sortedPrice["Price_Inflation"],
    line_kws={"color": "red", "linewidth": 1.5},
    ax=ax
)
# Out:
# <Axes: xlabel='Released Year', ylabel='Price_Inflation'>

# %%
fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(
    x=sortedPrice["Released Year"],
    y=sortedPrice["Units sold (million)"],
    line_kws={"color": "red", "linewidth": 1.5},
    ax=ax
)
# Out:
# <Axes: xlabel='Released Year', ylabel='Units sold (million)'>

# %% [markdown]
# Analyze: Get all of the consoles between decades and find out how many consoles launched that decade, also find out revenue, and compare that over time.

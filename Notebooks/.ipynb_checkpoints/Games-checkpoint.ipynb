# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
games = pd.read_csv('../Data/vgsales_new.csv')
games.head(2)
# Out:
#    Rank             Name Platform    Year    Genre Publisher  NA_Sales  \
# 0   259        Asteroids     2600  1980.0  Shooter     Atari      4.00
# 1   545  Missile Command     2600  1980.0  Shooter     Atari      2.56
#
#    NA_Total  EU_Sales  EU_Total  JP_Sales  JP_Total  Other_Sales  Other_Total  \
# 0   4000000      0.26    260000       0.0         0         0.05        50000
# 1   2560000      0.17    170000       0.0         0         0.03        30000
#
#    Global_Sales  Global_Total       Mods
# 0          4.31       4310000  1,000,000
# 1          2.76       2760000        NaN

# %%
games = games.drop(columns= 'Mods')

# %%
games.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   NA_Total      16598 non-null  int64
#  8   EU_Sales      16598 non-null  float64
#  9   EU_Total      16598 non-null  int64
#  10  JP_Sales      16598 non-null  float64
#  11  JP_Total      16598 non-null  int64
#  12  Other_Sales   16598 non-null  float64
#  13  Other_Total   16598 non-null  int64
#  14  Global_Sales  16598 non-null  float64
#  15  Global_Total  16598 non-null  int64
# dtypes: float64(6), int64(6), object(4)
# memory usage: 2.0+ MB

# %%
games['Year'].value_counts(dropna=False)
# Out:
# Year
# 2009.0    1431
# 2008.0    1428
# 2010.0    1259
# 2007.0    1202
# 2011.0    1139
# 2006.0    1008
# 2005.0     941
# 2002.0     829
# 2003.0     775
# 2004.0     763
# 2012.0     657
# 2015.0     614
# 2014.0     582
# 2013.0     546
# 2001.0     482
# 1998.0     379
# 2000.0     349
# 2016.0     344
# 1999.0     338
# 1997.0     289
# NaN        271
# 1996.0     263
# 1995.0     219
# 1994.0     121
# 1993.0      60
# 1981.0      46
# 1992.0      43
# 1991.0      41
# 1982.0      36
# 1986.0      21
# 1983.0      17
# 1989.0      17
# 1990.0      16
# 1987.0      16
# 1988.0      15
# 1984.0      14
# 1985.0      14
# 1980.0       9
# 2017.0       3
# 2020.0       1
# Name: count, dtype: int64

# %%
games['Decade'] = (games['Year'] // 10) * 10

# %%
games.head()
# Out:
#    Rank             Name Platform    Year     Genre   Publisher  NA_Sales  \
# 0   259        Asteroids     2600  1980.0   Shooter       Atari      4.00
# 1   545  Missile Command     2600  1980.0   Shooter       Atari      2.56
# 2  1768          Kaboom!     2600  1980.0      Misc  Activision      1.07
# 3  1971         Defender     2600  1980.0      Misc       Atari      0.99
# 4  2671           Boxing     2600  1980.0  Fighting  Activision      0.72
#
#    NA_Total  EU_Sales  EU_Total  JP_Sales  JP_Total  Other_Sales  Other_Total  \
# 0   4000000      0.26    260000       0.0         0         0.05        50000
# 1   2560000      0.17    170000       0.0         0         0.03        30000
# 2   1070000      0.07     70000       0.0         0         0.01        10000
# 3    990000      0.05     50000       0.0         0         0.01        10000
# 4    720000      0.04     40000       0.0         0         0.01        10000
#
#    Global_Sales  Global_Total  Decade
# 0          4.31       4310000  1980.0
# 1          2.76       2760000  1980.0
# 2          1.15       1150000  1980.0
# 3          1.05       1050000  1980.0
# 4          0.77        770000  1980.0

# %%
games['Decade'].value_counts()
# Out:
# Decade
# 2000.0    9208
# 2010.0    5144
# 1990.0    1769
# 1980.0     205
# 2020.0       1
# Name: count, dtype: int64

# %%
games_by_platform = games.groupby('Platform').agg({'Global_Total': 'sum'}).reset_index()
games_by_platform
# Out:
#    Platform  Global_Total
# 0      2600      97080000
# 1       3DO        100000
# 2       3DS     247460000
# 3        DC      15970000
# 4        DS     822490000
# 5        GB     255450000
# 6       GBA     318500000
# 7        GC     199360000
# 8       GEN      28360000
# 9        GG         40000
# 10      N64     218880000
# 11      NES     251070000
# 12       NG       1440000
# 13       PC     258820000
# 14     PCFX         30000
# 15       PS     730660000
# 16      PS2    1255640000
# 17      PS3     957840000
# 18      PS4     278100000
# 19      PSP     296280000
# 20      PSV      61930000
# 21      SAT      33590000
# 22      SCD       1870000
# 23     SNES     200050000
# 24     TG16        160000
# 25       WS       1420000
# 26      Wii     926710000
# 27     WiiU      81860000
# 28     X360     979960000
# 29       XB     258260000
# 30     XOne     141060000

# %% [markdown]
# Why did the ps2 have so many game sales? More games? More variety?

# %%
games_per_console = games.groupby('Platform').agg(
    game_count=('Name', 'count'),
    genre_count=('Genre', 'nunique'),
    publisher_count=('Publisher', 'nunique'))
games_per_console
# Out:
#           game_count  genre_count  publisher_count
# Platform
# 2600             133           10               26
# 3DO                3            3                3
# 3DS              509           12               81
# DC                52            9               15
# DS              2163           12              175
# GB                98           11               17
# GBA              822           12               87
# GC               556           12               52
# GEN               27           10                7
# GG                 1            1                1
# N64              319           12               54
# NES               98           10               12
# NG                12            2                3
# PC               960           12              130
# PCFX               1            1                1
# PS              1196           12              151
# PS2             2161           12              172
# PS3             1329           12              104
# PS4              336           12               67
# PSP             1213           12              127
# PSV              413           12               67
# SAT              173           12               44
# SCD                6            5                1
# SNES             239           12               50
# TG16               2            2                2
# WS                 6            2                2
# Wii             1325           12              113
# WiiU             143           12               23
# X360            1265           12              101
# XB               824           12               73
# XOne             213           11               40

# %%
threshold = games['Global_Total'].quantile(0.95)
games['Blockbuster'] = games['Global_Total'] >= threshold

# %%
games
# Out:
#         Rank                         Name Platform    Year         Genre  \
# 0        259                    Asteroids     2600  1980.0       Shooter
# 1        545              Missile Command     2600  1980.0       Shooter
# 2       1768                      Kaboom!     2600  1980.0          Misc
# 3       1971                     Defender     2600  1980.0          Misc
# 4       2671                       Boxing     2600  1980.0      Fighting
# ...      ...                          ...      ...     ...           ...
# 16593  16310                Freaky Flyers       GC     NaN        Racing
# 16594  16330                    Inversion       PC     NaN       Shooter
# 16595  16369  Hakuouki: Shinsengumi Kitan      PS3     NaN     Adventure
# 16596  16430                 Virtua Quest       GC     NaN  Role-Playing
# 16597  16496                   The Smurfs      3DS     NaN        Action
#
#                 Publisher  NA_Sales  NA_Total  EU_Sales  EU_Total  JP_Sales  \
# 0                   Atari      4.00   4000000      0.26    260000       0.0
# 1                   Atari      2.56   2560000      0.17    170000       0.0
# 2              Activision      1.07   1070000      0.07     70000       0.0
# 3                   Atari      0.99    990000      0.05     50000       0.0
# 4              Activision      0.72    720000      0.04     40000       0.0
# ...                   ...       ...       ...       ...       ...       ...
# 16593             Unknown      0.01     10000      0.00         0       0.0
# 16594  Namco Bandai Games      0.01     10000      0.00         0       0.0
# 16595             Unknown      0.01     10000      0.00         0       0.0
# 16596             Unknown      0.01     10000      0.00         0       0.0
# 16597             Unknown      0.00         0      0.01     10000       0.0
#
#        JP_Total  Other_Sales  Other_Total  Global_Sales  Global_Total  Decade  \
# 0             0         0.05        50000          4.31       4310000  1980.0
# 1             0         0.03        30000          2.76       2760000  1980.0
# 2             0         0.01        10000          1.15       1150000  1980.0
# 3             0         0.01        10000          1.05       1050000  1980.0
# 4             0         0.01        10000          0.77        770000  1980.0
# ...         ...          ...          ...           ...           ...     ...
# 16593         0         0.00            0          0.01         10000     NaN
# 16594         0         0.00            0          0.01         10000     NaN
# 16595         0         0.00            0          0.01         10000     NaN
# 16596         0         0.00            0          0.01         10000     NaN
# 16597         0         0.00            0          0.01         10000     NaN
#
#        Blockbuster
# 0             True
# 1             True
# 2            False
# 3            False
# 4            False
# ...            ...
# 16593        False
# 16594        False
# 16595        False
# 16596        False
# 16597        False
#
# [16598 rows x 18 columns]

# %%
games[games['Blockbuster'] == True]
# Out:
#        Rank                                         Name Platform    Year  \
# 0       259                                    Asteroids     2600  1980.0
# 1       545                              Missile Command     2600  1980.0
# 9       240                                     Pitfall!     2600  1981.0
# 10      736                                      Frogger     2600  1981.0
# 11      768                                 Demon Attack     2600  1981.0
# ...     ...                                          ...      ...     ...
# 16332   625                                    Rock Band     X360     NaN
# 16333   650     Frogger's Adventures: Temple of the Frog      GBA     NaN
# 16334   653  LEGO Indiana Jones: The Original Adventures      Wii     NaN
# 16335   713                               Call of Duty 3      Wii     NaN
# 16336   784                                    Rock Band      Wii     NaN
#
#            Genre                     Publisher  NA_Sales  NA_Total  EU_Sales  \
# 0        Shooter                         Atari      4.00   4000000      0.26
# 1        Shooter                         Atari      2.56   2560000      0.17
# 9       Platform                    Activision      4.21   4210000      0.24
# 10        Action                  Parker Bros.      2.06   2060000      0.12
# 11       Shooter                        Imagic      1.99   1990000      0.12
# ...          ...                           ...       ...       ...       ...
# 16332       Misc               Electronic Arts      1.93   1930000      0.34
# 16333  Adventure  Konami Digital Entertainment      2.15   2150000      0.18
# 16334     Action                     LucasArts      1.54   1540000      0.63
# 16335    Shooter                    Activision      1.19   1190000      0.84
# 16336       Misc                     MTV Games      1.35   1350000      0.56
#
#        EU_Total  JP_Sales  JP_Total  Other_Sales  Other_Total  Global_Sales  \
# 0        260000       0.0         0         0.05        50000          4.31
# 1        170000       0.0         0         0.03        30000          2.76
# 9        240000       0.0         0         0.05        50000          4.50
# 10       120000       0.0         0         0.02        20000          2.20
# 11       120000       0.0         0         0.02        20000          2.13
# ...         ...       ...       ...          ...          ...           ...
# 16332    340000       0.0         0         0.21       210000          2.48
# 16333    180000       0.0         0         0.07        70000          2.39
# 16334    630000       0.0         0         0.22       220000          2.39
# 16335    840000       0.0         0         0.23       230000          2.26
# 16336    560000       0.0         0         0.20       200000          2.11
#
#        Global_Total  Decade  Blockbuster
# 0           4310000  1980.0         True
# 1           2760000  1980.0         True
# 9           4500000  1980.0         True
# 10          2200000  1980.0         True
# 11          2130000  1980.0         True
# ...             ...     ...          ...
# 16332       2480000     NaN         True
# 16333       2390000     NaN         True
# 16334       2390000     NaN         True
# 16335       2260000     NaN         True
# 16336       2110000     NaN         True
#
# [836 rows x 18 columns]

# %% [markdown]
# 836 Blockbusters total.
# Analyze- Publisher share to see who take part in console success.

# %%
publisher_share = (
    games.groupby(['Platform', 'Publisher'])['Global_Total'].sum() / games.groupby('Platform')['Global_Total'].sum())
publisher_share
# Out:
# Platform  Publisher
# 2600      20th Century Fox Video Games              0.019984
#           Activision                                0.200041
#           Answer Software                           0.005150
#           Atari                                     0.515966
#           Avalon Interactive                        0.001751
#                                                       ...
# XOne      Telltale Games                            0.003261
#           Tru Blu Entertainment                     0.000354
#           Ubisoft                                   0.126967
#           Unknown                                   0.000213
#           Warner Bros. Interactive Entertainment    0.065220
# Name: Global_Total, Length: 1801, dtype: float64

# %%
publisher_share = publisher_share.to_frame()

# %%
type(publisher_share)
# Out:
# pandas.core.frame.DataFrame

# %%
publisher_share = publisher_share.reset_index()

# %%
publisher_share.dtypes
# Out:
# Platform         object
# Publisher        object
# Global_Total    float64
# dtype: object

# %%
decade_pct = (games['Decade'].value_counts(normalize=True).mul(100).rename('Percentage').reset_index().rename(columns={'index': 'Decade'}).sort_values('Decade').iloc[:-1])

# %%
decade_pct
# Out:
#    Decade  Percentage
# 3  1980.0    1.255589
# 2  1990.0   10.834813
# 0  2000.0   56.397379
# 1  2010.0   31.506094

# %%
colors = [
    '#3960EE',  # blue
    '#F73884',  # pink
    '#839CF2',  # softblue
    '#F57CAC'   # softpink
]

# %%
fig = plt.figure(figsize=(7,5))
plt.pie(decade_pct['Percentage'],
        autopct='%1.1f%%',
        startangle=90,
        colors=colors)
plt.title('Percentage of Games Released by Decade')
plt.legend(decade_pct['Decade'].astype(int))
plt.axis('equal')
plt.show()

# %%
fig.savefig('DecadePCTGames.png')

# %%
fig = plt.figure(figsize=(7,5))
plt.bar(decade_pct['Decade'].astype(int),
        decade_pct['Percentage'])
plt.title('Percentage of Games Released by Decade')
plt.xlabel('Decade')
plt.ylabel('Percentage')
plt.show()

# %%
year_2000 = decade_pct[decade_pct['Decade'] == 2000]['Percentage'].sum()
year_2000
# Out:
# np.float64(56.397378575365956)

# %%
other_years = decade_pct[decade_pct['Decade'] != 2000]['Percentage'].sum()
other_years
# Out:
# np.float64(43.59649660072273)

# %%
new_pie = pd.DataFrame({'Category': ["2000's", 'Other Years'], 'Percentage': [year_2000, other_years]})
new_pie
# Out:
#       Category  Percentage
# 0       2000's   56.397379
# 1  Other Years   43.596497

# %%
fig = plt.figure(figsize=(7,5))
plt.pie(new_pie['Percentage'],
        labels=new_pie['Category'],
        autopct='%1.1f%%',
        startangle=90,
        colors=colors)
plt.axis('equal')
plt.show()

# %%
fig.savefig('2000PCTGames.png')
